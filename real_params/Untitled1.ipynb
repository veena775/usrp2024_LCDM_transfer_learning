# %%
import numpy as np

# Load the file into a numpy array (replace 'your_file.txt' with your actual file path)
data = np.loadtxt('fR_params_lcdm.txt')

# Remove the last two columns by slicing the array
data_without_first_and_last_two_columns = data[:, 1:-2]

# Save the modified data to a new file (replace 'modified_file.txt' with your desired output file name)
np.savetxt('fR_params_lcdm.txt', data_without_last_two_columns, fmt='%.8e')


# Optionally, print a message to confirm it's saved
print("File saved as 'modified_file.txt'")
# Out:
# File saved as 'modified_file.txt'
